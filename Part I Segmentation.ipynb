# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import scipy

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import os
from sklearn.preprocessing import StandardScaler

from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import pickle

# %%
os.getcwd()
os.chdir(r"C:\Users\Tina Bhadekar\OneDrive\Desktop\Data sets")

# %% [markdown]
# ### Import Data- index column = 0 as we are aware the first column is individual Ids

# %%
df_segmentation = pd.read_csv('segmentation data.csv', index_col = 0)

# %%
## Explore the data

# %%
df_segmentation.head()
# Out:
#            Sex  Marital status  Age  Education  Income  Occupation  \
# ID
# 100000001    0               0   67          2  124670           1
# 100000002    1               1   22          1  150773           1
# 100000003    0               0   49          1   89210           0
# 100000004    0               0   45          1  171565           1
# 100000005    0               0   53          1  149031           1
#
#            Settlement size
# ID
# 100000001                2
# 100000002                2
# 100000003                0
# 100000004                1
# 100000005                1

# %%
df_segmentation.describe()
# Out:
#                Sex  Marital status          Age   Education         Income  \
# count  2000.000000     2000.000000  2000.000000  2000.00000    2000.000000
# mean      0.457000        0.496500    35.909000     1.03800  120954.419000
# std       0.498272        0.500113    11.719402     0.59978   38108.824679
# min       0.000000        0.000000    18.000000     0.00000   35832.000000
# 25%       0.000000        0.000000    27.000000     1.00000   97663.250000
# 50%       0.000000        0.000000    33.000000     1.00000  115548.500000
# 75%       1.000000        1.000000    42.000000     1.00000  138072.250000
# max       1.000000        1.000000    76.000000     3.00000  309364.000000
#
#         Occupation  Settlement size
# count  2000.000000      2000.000000
# mean      0.810500         0.739000
# std       0.638587         0.812533
# min       0.000000         0.000000
# 25%       0.000000         0.000000
# 50%       1.000000         1.000000
# ...

# %%
###There are 2000 observations and mean for continuous variable Age and Income . 
##The means of categoriacl values are not valueable as they are 0 and 1's. 
#The Min and Max value helps we to know the disrtibution of numerical variable.

# %% [markdown]
# Correlation Estimate: -1 negative 0 not linerally independent and 1 positively

# %%
df_segmentation.corr()
# Out:
#                       Sex  Marital status       Age  Education    Income  \
# Sex              1.000000        0.566511 -0.182885   0.244838 -0.195146
# Marital status   0.566511        1.000000 -0.213178   0.374017 -0.073528
# Age             -0.182885       -0.213178  1.000000   0.654605  0.340610
# Education        0.244838        0.374017  0.654605   1.000000  0.233459
# Income          -0.195146       -0.073528  0.340610   0.233459  1.000000
# Occupation      -0.202491       -0.029490  0.108388   0.064524  0.680357
# Settlement size -0.300803       -0.097041  0.119751   0.034732  0.490881
#
#                  Occupation  Settlement size
# Sex               -0.202491        -0.300803
# Marital status    -0.029490        -0.097041
# Age                0.108388         0.119751
# Education          0.064524         0.034732
# Income             0.680357         0.490881
# Occupation         1.000000         0.571795
# Settlement size    0.571795         1.000000

# %%
###diagonally its one to itself and we see high corr between Age education and Occupation and Income

# %%
plt.figure(figsize=(12,9))
s= sns.heatmap(df_segmentation.corr(),annot=True, cmap='RdBu',vmin=-1,vmax=1)
s.set_yticklabels(s.get_yticklabels(),rotation=0,fontsize=12)
s.set_xticklabels(s.get_xticklabels(),rotation=90,fontsize=12)
plt.title("Corrrelation Heat map")
plt.show()

# %%
###Segmentation - similar consumers in to groups
## Visualise the raw data - Age and Income by scatter plot

# %%
plt.figure(figsize=(12,9))
plt.scatter(df_segmentation.iloc[:,2],df_segmentation.iloc[:,4])
plt.xlabel('Age')
plt.ylabel('Income')
plt.title('Visualization of Age & Income data')
# Out:
# Text(0.5, 1.0, 'Visualization of Age & Income data')

# %%
### we need to standardize the data as in data we have age 20 ---70 and their Income 1 lakh ----2 lakh 
##when we compare the dif is huge and we have treat equally

# %%
scaler=StandardScaler()
segmentation_std=scaler.fit_transform(df_segmentation)

# %% [markdown]
# Hierarchial Clustering- we need to find a horizontal line on dendrogram on which to cut

# %%
hier_clustering=linkage(segmentation_std,method='ward')

# %%
plt.figure(figsize=(12,9))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Observations')
plt.ylabel('Distance')
dendrogram(hier_clustering,truncate_mode='level',p=5,show_leaf_counts = False, no_labels = True)
plt.show()

# %%
wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i,init='k-means++',random_state=42)
    kmeans.fit(segmentation_std)
    wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize=(12,9))
plt.plot(range(1,11),wcss,marker='o',linestyle='--')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('K-means Clustering')
plt.show()

# %%
kmeans=KMeans(n_clusters=4,init='k-means++',random_state=42)

# %%
kmeans.fit(segmentation_std)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
df_segm_kmeans=df_segmentation.copy()
df_segm_kmeans['Segment K-means']=kmeans.labels_

# %%
df_segm_analysis=df_segm_kmeans.groupby(['Segment K-means']).mean()
df_segm_analysis
# Out:
#                       Sex  Marital status        Age  Education  \
# Segment K-means
# 0                0.501901        0.692015  55.703422   2.129278
# 1                0.352814        0.019481  35.577922   0.746753
# 2                0.029825        0.173684  35.635088   0.733333
# 3                0.853901        0.997163  28.963121   1.068085
#
#                         Income  Occupation  Settlement size
# Segment K-means
# 0                158338.422053    1.129278         1.110266
# 1                 97859.852814    0.329004         0.043290
# 2                141218.249123    1.271930         1.522807
# 3                105759.119149    0.634043         0.422695

# %% [markdown]
# #### The first segment is composed of men and women equally with mean age is 56 but when compared to other segment it is the oldest seg and they have highest well of income and two third are in reln and have highest level of education we can call them WELLOFF
# ### two third of males and all are single their age is 36,education is low ,Sal and job is low and lives in small cities FEWER OPPORTUNITIES
# ##  fourth segment are in reln and avg age is 36 avg income and jobs and equally distributed so we name this as STANDARD
# # third segment entirely men and less than 20% are in reln relative low value for education and high level for Income and occupation living across 'CAREER FOCUSSED'

# %%
df_segm_analysis['N Obs']=df_segm_kmeans[['Segment K-means','Sex']].groupby(['Segment K-means']).count()
df_segm_analysis['Prop Obs']=df_segm_analysis[['N Obs']]/df_segm_analysis['N Obs'].sum()
df_segm_analysis
# Out:
#                       Sex  Marital status        Age  Education  \
# Segment K-means
# 0                0.501901        0.692015  55.703422   2.129278
# 1                0.352814        0.019481  35.577922   0.746753
# 2                0.029825        0.173684  35.635088   0.733333
# 3                0.853901        0.997163  28.963121   1.068085
#
#                         Income  Occupation  Settlement size  N Obs  Prop Obs
# Segment K-means
# 0                158338.422053    1.129278         1.110266    263    0.1315
# 1                 97859.852814    0.329004         0.043290    462    0.2310
# 2                141218.249123    1.271930         1.522807    570    0.2850
# 3                105759.119149    0.634043         0.422695    705    0.3525

# %%
df_segm_analysis.rename=({0:'Well-off',
                          1:'Fewer-Opportunities',
                          2:'Standarad',
                          3:'Career Focussed'})

# %%
df_segm_analysis.rename
# Out:
# {0: 'Well-off', 1: 'Fewer-Opportunities', 2: 'Standarad', 3: 'Career Focussed'}

# %%
df_segm_kmeans['Labels']=df_segm_kmeans['Segment K-means'].map({0:'Well-off',
                          1:'Fewer-Opportunities',
                          2:'Standarad',
                          3:'Career Focussed'})

# %%
x_axis=df_segm_kmeans['Age']
y_axis=df_segm_kmeans['Income']
plt.figure(figsize=(10,8))
sns.scatterplot(x_axis,y_axis,hue=df_segm_kmeans['Labels'],palette=['g','r','c','m'])
plt.title('Segmentation K-means')
plt.show()

# %%
pca=PCA()

# %%
pca.fit(segmentation_std)
# Out:
# PCA()

# %%
## Components are araranged in order of Importance

# %%
pca.explained_variance_ratio_
# Out:
# array([0.35696328, 0.26250923, 0.18821114, 0.0755775 , 0.05716512,
#        0.03954794, 0.02002579])

# %% [markdown]
# ### explains variability of Data and their sum is always 1...finding the subset of components ,while preserving variance

# %%
plt.figure(figsize=(12,9))
plt.plot(range(1,8), pca.explained_variance_ratio_.cumsum(), marker='o', linestyle='--')
plt.title('Explained Variance by Components')
plt.xlabel('Number of Components')
plt.ylabel('CumulativeExplained Variance')
# Out:
# Text(0, 0.5, 'CumulativeExplained Variance')

# %% [markdown]
# ### we are doing this for understanding the dimensionality of reduction

# %%
pca=PCA(n_components=3)
pca.fit(segmentation_std)
# Out:
# PCA(n_components=3)

# %%
pca.components_
# Out:
# array([[-0.31469524, -0.19170439,  0.32609979,  0.15684089,  0.52452463,
#          0.49205868,  0.46478852],
#        [ 0.45800608,  0.51263492,  0.31220793,  0.63980683,  0.12468314,
#          0.01465779, -0.06963165],
#        [-0.29301261, -0.44197739,  0.60954372,  0.27560461, -0.16566231,
#         -0.39550539, -0.29568503]])

# %% [markdown]
# ##loading :correlation between an orignal variable and a component to 3 from 7

# %%
df_pca_comp=pd.DataFrame(data=pca.components_,columns=df_segmentation.columns.values,
                        index=['Component 1','Component 2','Component 3'])
df_pca_comp
# Out:
#                   Sex  Marital status       Age  Education    Income  \
# Component 1 -0.314695       -0.191704  0.326100   0.156841  0.524525
# Component 2  0.458006        0.512635  0.312208   0.639807  0.124683
# Component 3 -0.293013       -0.441977  0.609544   0.275605 -0.165662
#
#              Occupation  Settlement size
# Component 1    0.492059         0.464789
# Component 2    0.014658        -0.069632
# Component 3   -0.395505        -0.295685

# %%
sns.heatmap(df_pca_comp,vmin=-1,vmax=1,cmap='RdBu',annot=True)
plt.yticks([0,1,2],
          ['Component 1','Component 2','Component 3'],rotation=45,fontsize=9)
# Out:
# ([<matplotlib.axis.YTick at 0x269f8959be0>,
# ...
#  [Text(0, 0.5, 'Component 1'),
#   Text(0, 1.5, 'Component 2'),
#   Text(0, 2.5, 'Component 3')])

# %%
#### there is positive correlation between age ,education , Income ,occupation and settlement size these relates for career focussed 
### second comp - are sex marital and education are correlatated - it relates to education and life style
# Marital st and occupation are negative - indidivdual loadings with absolute

# %%
pca.transform(segmentation_std)
# Out:
# array([[ 2.51474593,  0.83412239,  2.1748059 ],
#        [ 0.34493528,  0.59814564, -2.21160279],
#        [-0.65106267, -0.68009318,  2.2804186 ],
#        ...,
#        [-1.45229829, -2.23593665,  0.89657125],
#        [-2.24145254,  0.62710847, -0.53045631],
#        [-1.86688505, -2.45467234,  0.66262172]])

# %%
scores_pca=pca.transform(segmentation_std)

# %% [markdown]
# #  K means clustering with PCA

# %%
wcss=[]
for i in range(1,11):
    kmeans_pca=KMeans(n_clusters=i,init='k-means++',random_state=42)
    kmeans_pca.fit(scores_pca)
    wcss.append(kmeans_pca.inertia_)

# %%
plt.figure(figsize=(10,8))
plt.plot(range(1,11),wcss,marker='o',linestyle='--')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('K-means with PCA Clustering')
plt.show()

# %%
kmeans_pca=KMeans(n_clusters=4,init='k-means++',random_state=42)
kmeans_pca.fit(scores_pca)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
#  K means clustering with PCA with cluster=4

# %%
df_segm_pca_kmeans=pd.concat([df_segmentation.reset_index(drop=True),pd.DataFrame(scores_pca)],axis=1)
df_segm_pca_kmeans.columns.values[-3: ]= ['Component 1','Component 2','Component 3']
df_segm_pca_kmeans['Segment K-means PCA']=kmeans_pca.labels_
df_segm_pca_kmeans
# Out:
#       Sex  Marital status  Age  Education  Income  Occupation  \
# 0       0               0   67          2  124670           1
# 1       1               1   22          1  150773           1
# 2       0               0   49          1   89210           0
# 3       0               0   45          1  171565           1
# 4       0               0   53          1  149031           1
# ...   ...             ...  ...        ...     ...         ...
# 1995    1               0   47          1  123525           0
# 1996    1               1   27          1  117744           1
# 1997    0               0   31          0   86400           0
# 1998    1               1   24          1   97968           0
# 1999    0               0   25          0   68416           0
#
#       Settlement size  Component 1  Component 2  Component 3  \
# 0                   2     2.514746     0.834122     2.174806
# 1                   2     0.344935     0.598146    -2.211603
# ...

# %%
df_segm_pca_kmeans_freq=df_segm_pca_kmeans.groupby(['Segment K-means PCA']).mean()
df_segm_pca_kmeans_freq
# Out:
#                           Sex  Marital status        Age  Education  \
# Segment K-means PCA
# 0                    0.307190        0.098039  35.383442   0.766885
# 1                    0.027350        0.167521  35.700855   0.731624
# 2                    0.900433        0.965368  28.913420   1.062049
# 3                    0.505703        0.688213  55.722433   2.129278
#
#                             Income  Occupation  Settlement size  Component 1  \
# Segment K-means PCA
# 0                     93566.102397    0.248366         0.039216    -1.048838
# 1                    141489.721368    1.266667         1.475214     1.367167
# 2                    107551.946609    0.676768         0.440115    -1.106918
# 3                    158391.676806    1.129278         1.110266     1.706153
#
#                      Component 2  Component 3
# Segment K-means PCA
# 0                      -0.892116     1.010446
# 1                      -1.050209    -0.247981
# ...

# %%
###the third components is low on career and high on Edu & Lifestyle-----standard
### the second shows high value for career but low for edu lifestyle and exp-----Career focussed 
### the first is low on acreer and edu - ----Fewer opportunities
### the fourth is hig on all ----this is Well off seg

# %%
df_segm_pca_kmeans_freq['N Obs']=df_segm_pca_kmeans[['Segment K-means PCA','Sex']].groupby(['Segment K-means PCA']).count()
df_segm_pca_kmeans_freq['Prop Obs']=df_segm_pca_kmeans_freq['N Obs']/df_segm_pca_kmeans_freq['N Obs'].sum()
df_segm_pca_kmeans_freq=df_segm_pca_kmeans_freq.rename({3:'Well-off',
                                                        0:'Fewer-Opportunities',
                                                        1:'Career-Focussed',
                                                        2:'Standard'})
df_segm_pca_kmeans_freq
# Out:
#                           Sex  Marital status        Age  Education  \
# Segment K-means PCA
# Fewer-Opportunities  0.307190        0.098039  35.383442   0.766885
# Career-Focussed      0.027350        0.167521  35.700855   0.731624
# Standard             0.900433        0.965368  28.913420   1.062049
# Well-off             0.505703        0.688213  55.722433   2.129278
#
#                             Income  Occupation  Settlement size  Component 1  \
# Segment K-means PCA
# Fewer-Opportunities   93566.102397    0.248366         0.039216    -1.048838
# Career-Focussed      141489.721368    1.266667         1.475214     1.367167
# Standard             107551.946609    0.676768         0.440115    -1.106918
# Well-off             158391.676806    1.129278         1.110266     1.706153
#
#                      Component 2  Component 3  N Obs  Prop Obs
# Segment K-means PCA
# Fewer-Opportunities    -0.892116     1.010446    459    0.2295
# ...

# %%
df_segm_pca_kmeans['Legend']=df_segm_pca_kmeans['Segment K-means PCA'].map({3:'Well-off',
                                                        0:'Fewer-Opportunities',
                                                        1:'Career-Focussed',
                                                        2:'Standard'})

# %%
x_axis=df_segm_pca_kmeans['Component 2']
y_axis=df_segm_pca_kmeans['Component 1']
plt.figure(figsize=(10,8))
sns.scatterplot(x_axis,y_axis,hue=df_segm_pca_kmeans['Legend'],palette=['g','r','c','m'])
plt.title('Clusters by PCA Components')
# Out:
# Text(0.5, 1.0, 'Clusters by PCA Components')

# %%
#𝐏𝐥𝐨𝐭 𝐃𝐚𝐭𝐚 𝐛𝐲 𝐏𝐂𝐀 𝐂𝐨𝐦𝐩𝐨𝐧𝐞𝐧𝐭𝐬 1 𝐚𝐧𝐝 3

# %%
x_axis_1 = df_segm_pca_kmeans['Component 3']
y_axis_1 = df_segm_pca_kmeans['Component 1']
plt.figure(figsize = (12, 9))
sns.scatterplot(x_axis_1, y_axis_1, hue = df_segm_pca_kmeans['Legend'], palette = ['g', 'r', 'c', 'm'])
plt.title('Clusters by PCA Components' )
plt.show()

# %%
#𝐏𝐥𝐨𝐭 𝐃𝐚𝐭𝐚 𝐛𝐲 𝐏𝐂𝐀 𝐂𝐨𝐦𝐩𝐨𝐧𝐞𝐧𝐭𝐬 2 𝐚𝐧𝐝 3

# %%
x_axis_1 = df_segm_pca_kmeans['Component 3']
y_axis_1 = df_segm_pca_kmeans['Component 2']
plt.figure(figsize = (12, 9))
sns.scatterplot(x_axis_1, y_axis_1, hue = df_segm_pca_kmeans['Legend'], palette = ['g', 'r', 'c', 'm'])
plt.title('Clusters by PCA Components' )
plt.show()

# %% [markdown]
# Data Export

# %%
pickle.dump(scaler, open('scaler.pickle', 'wb'))

# %%
pickle.dump(pca, open('pca.pickle', 'wb'))
pickle.dump(kmeans_pca, open('kmeans_pca.pickle', 'wb'))
